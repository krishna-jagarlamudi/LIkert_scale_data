# %%
import pandas as pd

# %%
# Load the data
data_new = pd.read_excel("/Users/krishnajagarlamudi/Downloads/S2BLD.XLSX")

# Display the first few rows of the dataframe
data_new.head()
# Out:
#                      Major:  \
# 0          Computer Science
# 1      Software Engineering
# 2  Mechatronics Engineering
# 3          Computer Science
# 4      Computer Engineering
#
#   Course ID/Section : (CSE 1300 OR CSE 1321 OR CSE 1322) Gender:  \
# 0                                            SWE3643        Male
# 1                                CSE 1321 section 04      Female
# 2                                   1321 Section E01      Female
# 3                                CCSE1321 Section 04      Female
# 4                              CSE 1321  Section H01        Male
#
#                            Race:  \
# 0               South East Asian
# 1  White, Asian, native American
# 2                            NaN
# 3                          Asian
# 4                          Asian
#
#   To solve problems, I draw on my ability to hold, accept and go beyond paradoxes  \
# 0                                            Neutral
# 1                                              Agree
# 2                                            Neutral
# 3                                              Agree
# 4                                              Agree
#
#   I can hold as true and integrate seemingly conflicting or contradictory points of view   \
# 0                                            Neutral
# 1                                              Agree
# 2                                              Agree
# 3                                            Neutral
# 4                                              Agree
#
#   I can offer new ways of looking at a problem  \
# 0                                      Neutral
# 1                               Strongly agree
# 2                                        Agree
# 3                                        Agree
# 4                                        Agree
#
#   I find unusual ways to solve a problem   \
# 0                                 Neutral
# 1                          Strongly agree
# 2                                 Neutral
# 3                                 Neutral
# 4                                   Agree
#
#   I display curiosity about many things   \
# 0                                Neutral
# 1                         Strongly agree
# 2                                  Agree
# 3                                Neutral
# 4                         Strongly agree
#
#   I am willing to change my mind and try something else   ...  \
# 0                                            Neutral      ...
# 1                                     Strongly agree      ...
# 2                                              Agree      ...
# 3                                              Agree      ...
# 4                                     Strongly agree      ...
#
#   I understand that there are shared knowledge and skills between team members  \
# 0                                              Agree
# 1                                     Strongly agree
# 2                                              Agree
# 3                                              Agree
# 4                                     Strongly agree
#
#   I can create a cooperative atmosphere among the members when addressing problems  \
# 0                                              Agree
# 1                                     Strongly agree
# 2                                              Agree
# 3                                              Agree
# 4                                     Strongly agree
#
#   I can listen to and consider other members' opinions  \
# 0                                            Neutral
# 1                                     Strongly agree
# 2                                              Agree
# 3                                              Agree
# 4                                     Strongly agree
#
#   I am willing to ask others for help I can trust other team members  \
# 0                            Disagree                        Neutral
# 1                      Strongly agree                          Agree
# 2                               Agree                          Agree
# 3                               Agree                        Neutral
# 4                      Strongly agree                          Agree
#
#   I can set aside differences when working with others to achieve a common goal  \
# 0                                              Agree
# 1                                     Strongly agree
# 2                                              Agree
# 3                                              Agree
# 4                                              Agree
#
#   I like experiencing cooperative learning together with my group/ friends  \
# 0                                            Neutral
# 1                                     Strongly agree
# 2                                              Agree
# 3                                            Neutral
# 4                                              Agree
#
#   In cooperative learning, I think I attain more success  \
# 0                                            Neutral
# 1                                              Agree
# 2                                              Agree
# 3                                              Agree
# 4                                              Agree
#
#   I like solving problems related to group projects together with my friends in cooperative learning  \
# 0                                            Neutral
# 1                                     Strongly agree
# 2                                              Agree
# 3                                              Agree
# 4                                              Agree
#
#   More ideas occur in cooperative learning
# 0                                    Agree
# 1                           Strongly agree
# 2                                    Agree
# 3                                    Agree
# 4                           Strongly agree
#
# [5 rows x 54 columns]

# %%
# Standardize the Major, Gender, and Race categories
data_new["Major:"] = data_new["Major:"].str.lower().str.strip()
data_new["Gender:"] = data_new["Gender:"].str.lower().str.strip()
data_new["Race:"] = data_new["Race:"].str.lower().str.strip()

# Display the unique values in each of these columns
major_unique = data_new["Major:"].unique()
gender_unique = data_new["Gender:"].unique()
race_unique = data_new["Race:"].unique()

major_unique, gender_unique, race_unique
# Out:
# (array(['computer science', 'software engineering',
#         'mechatronics engineering', 'computer engineering',
#         'software eingeering', 'cyber securuty', 'cybersecurity',
#         'mechatronics', 'information technology', 'software engineer',
#         'cyber security', 'cse', 'computer game design and development',
#         'computer science and computer engineering', 'biology',
#         'game design and development', 'cs',
#         'computer science and human service', 'it',
#         'bachelor of science in software engineering',
#         'electrical engineering', 'computer scoence', 'cgdd',
#         'it (cybersecurity)', 'computer software engineering',
#         'undeclared', 'mathematics', 'criminal justice',
#         'computer science and game design (double major)',
#         'information tecnology', 'mechatronics and robotics engineering',
#         'industrial engineering', 'undecided',
#         'computer science & engineering concentration: artificial intelligence',
#         'iinformation technology', 'civil engineering (cs minor)',
#         'cgdd - computer game development & design',
#         'mechanical engineering'], dtype=object),
#  array(['male', 'female', nan, 'transgender male', 'woman', 'man',
#         'nonbinary', 'femal', '?', 'male - he/him/his'], dtype=object),
#  array(['south east asian', 'white, asian, native american', nan, 'asian',
#         'indian american', 'white', 'african american', 'hispanic',
#         'white/asian', 'caucasian', 'black/african american', 'black',
#         'white/ hispanic', 'latino', 'middle eastern', 'white/caucasian',
#         'hispanic/latino', 'asian/white', 'mixed - black/asian',
#         'south asian', 'african america', 'multi-racial', 'latinx',
#         'afro-caribbean', 'two or more race (white and asian)',
#         'asian/pacific islander', 'black/african-american'], dtype=object))

# %%
# Define mappings for standardizing the categories
gender_mapping = {
    "man": "male",
    "he/him/male": "male",
    "make": "male",
    "m": "male",
    "female ": "female",
    "male ": "male",
}

race_mapping = {
    "african american": "black",
    "african american/black": "black",
    "black or african american": "black",
    "black...": "black",
    "black =": "black",
    "black/african american": "black",
    "african-american": "black",
    "black...": "black",
    "african-american ": "black",
    "african american ": "black",
    "caucasian": "white",
    "white/caucasian": "white",
    "white/non-hispanic": "white",
    "white (ethnicity : hispanic)": "white",
    "white/ hispanic": "white",
    "caucasian ": "white",
    "white ": "white",
}

# Apply the mappings to the data
data_new["Gender:"] = data_new["Gender:"].replace(gender_mapping)
data_new["Race:"] = data_new["Race:"].replace(race_mapping)

# Display the unique values in each of these columns after the mapping
major_unique = data_new["Major:"].unique()
gender_unique = data_new["Gender:"].unique()
race_unique = data_new["Race:"].unique()

major_unique, gender_unique, race_unique
# Out:
# (array(['computer science', 'software engineering',
#         'mechatronics engineering', 'computer engineering',
#         'software eingeering', 'cyber securuty', 'cybersecurity',
#         'mechatronics', 'information technology', 'software engineer',
#         'cyber security', 'cse', 'computer game design and development',
#         'computer science and computer engineering', 'biology',
#         'game design and development', 'cs',
#         'computer science and human service', 'it',
#         'bachelor of science in software engineering',
#         'electrical engineering', 'computer scoence', 'cgdd',
#         'it (cybersecurity)', 'computer software engineering',
#         'undeclared', 'mathematics', 'criminal justice',
#         'computer science and game design (double major)',
#         'information tecnology', 'mechatronics and robotics engineering',
#         'industrial engineering', 'undecided',
#         'computer science & engineering concentration: artificial intelligence',
#         'iinformation technology', 'civil engineering (cs minor)',
#         'cgdd - computer game development & design',
#         'mechanical engineering'], dtype=object),
#  array(['male', 'female', nan, 'transgender male', 'woman', 'nonbinary',
#         'femal', '?', 'male - he/him/his'], dtype=object),
#  array(['south east asian', 'white, asian, native american', nan, 'asian',
#         'indian american', 'white', 'black', 'hispanic', 'white/asian',
#         'latino', 'middle eastern', 'hispanic/latino', 'asian/white',
#         'mixed - black/asian', 'south asian', 'african america',
#         'multi-racial', 'latinx', 'afro-caribbean',
#         'two or more race (white and asian)', 'asian/pacific islander',
#         'black/african-american'], dtype=object))

# %%
# Define a mapping for the Likert scale responses
likert_mapping = {
    "Strongly disagree": 1,
    "Disagree": 2,
    "Neutral": 3,
    "Agree": 4,
    "Strongly agree": 5
}

# Apply the mapping to the Likert scale columns
likert_columns = data_new.columns[4:]
data_new[likert_columns] = data_new[likert_columns].replace(likert_mapping)

# Display the first few rows of the dataframe to confirm the changes
data_new.head()
# Out:
#                      Major:  \
# 0          computer science
# 1      software engineering
# 2  mechatronics engineering
# 3          computer science
# 4      computer engineering
#
#   Course ID/Section : (CSE 1300 OR CSE 1321 OR CSE 1322) Gender:  \
# 0                                            SWE3643        male
# 1                                CSE 1321 section 04      female
# 2                                   1321 Section E01      female
# 3                                CCSE1321 Section 04      female
# 4                              CSE 1321  Section H01        male
#
#                            Race:  \
# 0               south east asian
# 1  white, asian, native american
# 2                            NaN
# 3                          asian
# 4                          asian
#
#    To solve problems, I draw on my ability to hold, accept and go beyond paradoxes  \
# 0                                                  3
# 1                                                  4
# 2                                                  3
# 3                                                  4
# 4                                                  4
#
#   I can hold as true and integrate seemingly conflicting or contradictory points of view   \
# 0                                                  3
# 1                                                  4
# 2                                                  4
# 3                                                  3
# 4                                                  4
#
#   I can offer new ways of looking at a problem  \
# 0                                            3
# 1                                            5
# 2                                            4
# 3                                            4
# 4                                            4
#
#   I find unusual ways to solve a problem   \
# 0                                       3
# 1                                       5
# 2                                       3
# 3                                       3
# 4                                       4
#
#    I display curiosity about many things   \
# 0                                       3
# 1                                       5
# 2                                       4
# 3                                       3
# 4                                       5
#
#    I am willing to change my mind and try something else   ...  \
# 0                                                  3       ...
# 1                                                  5       ...
# 2                                                  4       ...
# 3                                                  4       ...
# 4                                                  5       ...
#
#   I understand that there are shared knowledge and skills between team members  \
# 0                                                  4
# 1                                                  5
# 2                                                  4
# 3                                                  4
# 4                                                  5
#
#   I can create a cooperative atmosphere among the members when addressing problems  \
# 0                                                  4
# 1                                                  5
# 2                                                  4
# 3                                                  4
# 4                                                  5
#
#    I can listen to and consider other members' opinions  \
# 0                                                  3
# 1                                                  5
# 2                                                  4
# 3                                                  4
# 4                                                  5
#
#    I am willing to ask others for help  I can trust other team members  \
# 0                                    2                               3
# 1                                    5                               4
# 2                                    4                               4
# 3                                    4                               3
# 4                                    5                               4
#
#    I can set aside differences when working with others to achieve a common goal  \
# 0                                                  4
# 1                                                  5
# 2                                                  4
# 3                                                  4
# 4                                                  4
#
#    I like experiencing cooperative learning together with my group/ friends  \
# 0                                                  3
# 1                                                  5
# 2                                                  4
# 3                                                  3
# 4                                                  4
#
#    In cooperative learning, I think I attain more success  \
# 0                                                  3
# 1                                                  4
# 2                                                  4
# 3                                                  4
# 4                                                  4
#
#    I like solving problems related to group projects together with my friends in cooperative learning  \
# 0                                                  3
# 1                                                  5
# 2                                                  4
# 3                                                  4
# 4                                                  4
#
#    More ideas occur in cooperative learning
# 0                                         4
# 1                                         5
# 2                                         4
# 3                                         4
# 4                                         5
#
# [5 rows x 54 columns]

# %%
import numpy as np

# %%
# 1. Convert all Likert scale responses to numeric values
data_new[likert_columns] = data_new[likert_columns].apply(pd.to_numeric, errors='coerce')

# 2. Flatten the Likert scale responses into a single array (from a DataFrame format to a 1D array)
likert_data_flat = data_new[likert_columns].values.flatten()

# 3. Filter out any NaN values from the array (this step ensures that any non-numeric values are excluded)
likert_data_flat = likert_data_flat[~np.isnan(likert_data_flat)]

# 4. Count the number of each type of response (from 1 to 5)
category_counts = pd.value_counts(likert_data_flat, sort=False)

# 5. Calculate the percentage distribution of each type of response
overall_percentages = (category_counts / len(likert_data_flat)) * 100

# 6. Sort the percentages in ascending order of response type
overall_percentages.sort_index()
# Out:
# 1.0     1.224255
# 2.0     6.150079
# 3.0    16.232176
# 4.0    42.474435
# 5.0    33.919055
# dtype: float64

# %%
# Function to calculate percentage for each category based on Major, Gender and Race
def calculate_percentages(category_field, category):
    # Filter the main data to get rows that match the given category and value.
    # For instance, if category_field is "Major:" and category is "Engineering",
    # it fetches all rows of students majoring in Engineering.
    data_category = data_new[data_new[category_field] == category][likert_columns]
    
    # Convert the 2D data (rows of Likert responses) to a 1D array for ease of processing.
    likert_data_flat = data_category.values.flatten()
    
    # Remove any NaN values from the array. This is essential for accurate percentage calculation.
    likert_data_flat = likert_data_flat[~np.isnan(likert_data_flat)]
    
    # Calculate the total number of responses in the flattened array.
    total_responses_category = len(likert_data_flat)
    
    # Count the occurrences of each Likert scale response (e.g., how many times was "Strongly Agree" chosen).
    category_counts = pd.value_counts(likert_data_flat, sort=False)
    
    # Calculate the percentage for each Likert scale response.
    percentages = (category_counts / total_responses_category) * 100
    
    # Return the sorted percentages. This ensures the order is from "Strongly disagree" to "Strongly agree".
    return percentages.sort_index()

# For each unique Major in the dataset, apply the calculate_percentages function.
# This computes the percentage distribution of Likert responses for every Major.
major_percentages = {major: calculate_percentages("Major:", major) for major in major_unique}

# Similarly, calculate the percentages for each unique value in the "Gender:" category.
gender_percentages = {gender: calculate_percentages("Gender:", gender) for gender in gender_unique}

# Similarly, calculate the percentages for each unique value in the "Race:" category.
race_percentages = {race: calculate_percentages("Race:", race) for race in race_unique}

major_percentages, gender_percentages, race_percentages
# Out:
# ({'computer science': 1.0     0.793351
#   2.0     5.553457
#   3.0    14.960332
#   4.0    43.029845
#   5.0    35.663015
#   dtype: float64,
#   'software engineering': 1.0     0.363636
#   2.0     2.181818
#   3.0    14.363636
#   4.0    44.181818
#   5.0    38.909091
#   dtype: float64,
#   'mechatronics engineering': 2.0     1.333333
#   3.0    16.666667
#   4.0    71.333333
#   5.0    10.666667
#   dtype: float64,
#   'computer engineering': 2.0     3.5
#   3.0     7.0
#   4.0    40.5
#   5.0    49.0
#   dtype: float64,
#   'software eingeering': 1.0     8.0
#   2.0     8.0
#   3.0    54.0
#   4.0    20.0
#   5.0    10.0
#   dtype: float64,
#   'cyber securuty': 2.0     2.0
#   3.0    12.0
#   4.0    24.0
#   5.0    62.0
#   dtype: float64,
#   'cybersecurity': 1.0     0.363636
#   2.0     7.818182
#   3.0    12.363636
#   4.0    46.363636
#   5.0    33.090909
#   dtype: float64,
#   'mechatronics': 2.0     6.666667
#   3.0    21.333333
#   4.0    51.333333
#   5.0    20.666667
#   dtype: float64,
#   'information technology': 1.0     1.821494
#   2.0     6.193078
#   3.0    24.772313
#   4.0    39.162113
#   5.0    28.051002
#   dtype: float64,
#   'software engineer': 2.0     2.0
#   3.0    10.0
#   4.0    32.0
#   5.0    56.0
#   dtype: float64,
#   'cyber security': 2.0     2.5
#   3.0    16.0
#   4.0    56.0
#   5.0    25.5
#   dtype: float64,
#   'cse': 2.0     8.0
#   3.0    22.0
#   4.0    51.0
#   5.0    19.0
#   dtype: float64,
#   'computer game design and development': 1.0     4.0
#   2.0    12.0
#   3.0    12.0
#   4.0    33.0
#   5.0    39.0
#   dtype: float64,
#   'computer science and computer engineering': 1.0     4.0
#   2.0     8.0
#   3.0     4.0
#   4.0    18.0
#   5.0    66.0
#   dtype: float64,
#   'biology': 1.0     4.0
#   2.0    10.0
#   3.0    12.0
#   4.0    22.0
#   5.0    52.0
#   dtype: float64,
#   'game design and development': 1.0     7.035176
#   2.0    12.060302
#   3.0    16.582915
#   4.0    41.206030
#   5.0    23.115578
#   dtype: float64,
#   'cs': 1.0     4.0
#   2.0    20.0
#   3.0    22.0
#   4.0    34.0
#   5.0    20.0
#   dtype: float64,
#   'computer science and human service': 2.0     6.0
#   3.0    12.0
#   4.0    38.0
#   5.0    44.0
#   dtype: float64,
#   'it': 1.0     3.333333
#   2.0    23.333333
#   3.0    28.000000
#   4.0    30.000000
#   5.0    15.333333
#   dtype: float64,
#   'bachelor of science in software engineering': 3.0    12.0
#   4.0    26.0
#   5.0    62.0
#   dtype: float64,
#   'electrical engineering': 2.0     3.0
#   3.0    17.0
#   4.0    47.0
#   5.0    33.0
#   dtype: float64,
#   'computer scoence': 1.0    16.326531
#   2.0     8.163265
#   3.0    18.367347
#   4.0    38.775510
#   5.0    18.367347
#   dtype: float64,
#   'cgdd': 1.0     2.020202
#   2.0    10.101010
#   3.0    30.303030
#   4.0    39.393939
#   5.0    18.181818
#   dtype: float64,
#   'it (cybersecurity)': 1.0     2.0
#   2.0    12.0
#   3.0    16.0
#   4.0    24.0
#   5.0    46.0
#   dtype: float64,
#   'computer software engineering': 2.0     4.0
#   3.0    12.0
#   4.0    48.0
#   5.0    36.0
#   dtype: float64,
#   'undeclared': 3.0     6.0
#   4.0    66.0
#   5.0    28.0
#   dtype: float64,
#   'mathematics': 1.0     2.0
#   2.0    16.0
#   3.0    18.0
#   4.0    44.0
#   5.0    20.0
#   dtype: float64,
#   'criminal justice': 2.0    10.0
#   3.0    18.0
#   4.0    44.0
#   5.0    28.0
#   dtype: float64,
#   'computer science and game design (double major)': 1.0    10.0
#   2.0     4.0
#   3.0    14.0
#   4.0    24.0
#   5.0    48.0
#   dtype: float64,
#   'information tecnology': 3.0    10.0
#   4.0    24.0
#   5.0    66.0
#   dtype: float64,
#   'mechatronics and robotics engineering': 2.0    12.0
#   3.0    24.0
#   4.0    40.0
#   5.0    24.0
#   dtype: float64,
#   'industrial engineering': 2.0     6.0
#   3.0    22.0
#   4.0    46.0
#   5.0    26.0
#   dtype: float64,
#   'undecided': 3.0    16.0
#   4.0    32.0
#   5.0    52.0
#   dtype: float64,
#   'computer science & engineering concentration: artificial intelligence': 2.0     6.0
#   3.0    16.0
#   4.0    24.0
#   5.0    54.0
#   dtype: float64,
#   'iinformation technology': 3.0     8.0
#   4.0    70.0
#   5.0    22.0
#   dtype: float64,
#   'civil engineering (cs minor)': 2.0    10.0
#   3.0    16.0
#   4.0    18.0
#   5.0    56.0
#   dtype: float64,
#   'cgdd - computer game development & design': 2.0     6.0
#   3.0    22.0
#   4.0    48.0
#   5.0    24.0
#   dtype: float64,
#   'mechanical engineering': 3.0     4.0
#   4.0    42.0
#   5.0    54.0
#   dtype: float64},
#  {'male': 1.0     1.081703
#   2.0     5.431530
#   3.0    15.903337
#   4.0    42.646720
#   5.0    34.936709
#   dtype: float64,
#   'female': 1.0     1.715920
#   2.0     7.912297
#   3.0    16.873213
#   4.0    42.087703
#   5.0    31.410867
#   dtype: float64,
#   nan: Series([], dtype: float64),
#   'transgender male': 2.0     6.0
#   3.0    12.0
#   4.0    38.0
#   5.0    44.0
#   dtype: float64,
#   'woman': 3.0    12.0
#   4.0    50.0
#   5.0    38.0
#   dtype: float64,
#   'nonbinary': 2.0     6.0
#   3.0     2.0
#   4.0    50.0
#   5.0    42.0
#   dtype: float64,
#   'femal': 2.0     6.0
#   3.0    16.0
#   4.0    24.0
#   5.0    54.0
#   dtype: float64,
#   '?': 2.0    10.0
#   3.0    16.0
#   4.0    18.0
#   5.0    56.0
#   dtype: float64,
#   'male - he/him/his': 2.0     6.0
#   3.0    22.0
#   4.0    48.0
#   5.0    24.0
#   dtype: float64},
#  {'south east asian': 2.0    10.0
#   3.0    68.0
#   4.0    22.0
#   dtype: float64,
#   'white, asian, native american': 3.0     2.0
#   4.0    32.0
#   5.0    66.0
#   dtype: float64,
#   nan: Series([], dtype: float64),
#   'asian': 1.0     0.480384
#   2.0     5.524420
#   3.0    14.971978
#   4.0    47.958367
#   5.0    31.064852
#   dtype: float64,
#   'indian american': 1.0     8.0
#   2.0     8.0
#   3.0    54.0
#   4.0    20.0
#   5.0    10.0
#   dtype: float64,
#   'white': 1.0     1.208146
#   2.0     6.351398
#   3.0    14.566793
#   4.0    41.284087
#   5.0    36.589575
#   dtype: float64,
#   'black': 1.0     1.684042
#   2.0     4.651163
#   3.0    14.595028
#   4.0    44.346431
#   5.0    34.723336
#   dtype: float64,
#   'hispanic': 2.0     4.000000
#   3.0    17.333333
#   4.0    52.000000
#   5.0    26.666667
#   dtype: float64,
#   'white/asian': 1.0     2.0
#   2.0     2.0
#   3.0    10.0
#   4.0    20.0
#   5.0    66.0
#   dtype: float64,
#   'latino': 1.0     3.0
#   2.0     6.0
#   3.0    11.0
#   4.0    31.0
#   5.0    49.0
#   dtype: float64,
#   'middle eastern': 1.0     2.000000
#   2.0    15.333333
#   3.0    25.333333
#   4.0    47.333333
#   5.0    10.000000
#   dtype: float64,
#   'hispanic/latino': 3.0    50.0
#   4.0    48.0
#   5.0     2.0
#   dtype: float64,
#   'asian/white': 2.0     8.0
#   3.0    16.0
#   4.0    46.0
#   5.0    30.0
#   dtype: float64,
#   'mixed - black/asian': 2.0    12.0
#   3.0     4.0
#   4.0    28.0
#   5.0    56.0
#   dtype: float64,
#   'south asian': 5.0    100.0
#   dtype: float64,
#   'african america': 1.0     6.0
#   2.0    10.0
#   3.0    32.0
#   4.0    30.0
#   5.0    22.0
#   dtype: float64,
#   'multi-racial': 1.0     4.0
#   2.0     2.0
#   3.0    16.0
#   4.0    18.0
#   5.0    60.0
#   dtype: float64,
#   'latinx': 2.0     4.0
#   3.0    12.0
#   4.0    48.0
#   5.0    36.0
#   dtype: float64,
#   'afro-caribbean': 2.0     4.0
#   3.0    16.0
#   4.0    36.0
#   5.0    44.0
#   dtype: float64,
#   'two or more race (white and asian)': 2.0    10.0
#   3.0     6.0
#   4.0    40.0
#   5.0    44.0
#   dtype: float64,
#   'asian/pacific islander': 2.0     6.0
#   3.0    22.0
#   4.0    46.0
#   5.0    26.0
#   dtype: float64,
#   'black/african-american': 2.0     6.0
#   3.0    22.0
#   4.0    48.0
#   5.0    24.0
#   dtype: float64})

# %%
import matplotlib.pyplot as plt
# Converting the major_percentages dictionary to a DataFrame for easy plotting
major_percentages_df = pd.DataFrame(major_percentages).transpose().fillna(0)

# Plotting the response percentages for each major as a stacked bar chart
major_percentages_df.plot(kind='bar', stacked=True, figsize=(12, 6), cmap='viridis', edgecolor='black')

# Adding details to the plot
plt.title('Response Percentages by Major')
plt.ylabel('Percentage')
plt.xlabel('Major')
plt.legend(title='Likert Scale Response', loc='upper left', bbox_to_anchor=(1, 1))
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

plt.show()

# %%
# Converting the gender_percentages and race_percentages dictionaries to DataFrames for easy plotting
gender_percentages_df = pd.DataFrame(gender_percentages).transpose().fillna(0)
race_percentages_df = pd.DataFrame(race_percentages).transpose().fillna(0)

# Plotting the response percentages for each gender
gender_percentages_df.plot(kind='bar', stacked=True, figsize=(10, 5), cmap='viridis', edgecolor='black')

# Adding details to the plot
plt.title('Response Percentages by Gender')
plt.ylabel('Percentage')
plt.xlabel('Gender')
plt.legend(title='Likert Scale Response', loc='upper left', bbox_to_anchor=(1, 1))
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

plt.show()

# Plotting the response percentages for each race
race_percentages_df.plot(kind='bar', stacked=True, figsize=(12, 6), cmap='viridis', edgecolor='black')

# Adding details to the plot
plt.title('Response Percentages by Race')
plt.ylabel('Percentage')
plt.xlabel('Race')
plt.legend(title='Likert Scale Response', loc='upper left', bbox_to_anchor=(1, 1))
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

plt.show()
