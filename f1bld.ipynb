# %%
import pandas as pd

# %%
# Load the data
data_new = pd.read_excel("/Users/krishnajagarlamudi/Downloads/F1BLD.XLSX")

# Display the first few rows of the dataframe
data_new.head()
# Out:
#   5W7yRTTxnkO8k-bH4z1hwh3ah9VzkdROk_z7sgux1h5UMU9LTkNYQjZJUjdZOUJRQjJPQ0wzOTlaWS4u
# 0                                              Form1
# 1             {6050b20a-ab47-4931-9033-65bce9b9daa0}

# %%
# Standardize the Major, Gender, and Race categories
data_new["Major:"] = data_new["Major:"].str.lower().str.strip()
data_new["Gender:"] = data_new["Gender:"].str.lower().str.strip()
data_new["Race:"] = data_new["Race:"].str.lower().str.strip()

# Display the unique values in each of these columns
major_unique = data_new["Major:"].unique()
gender_unique = data_new["Gender:"].unique()
race_unique = data_new["Race:"].unique()

major_unique, gender_unique, race_unique
# Out:
# (array(['re', 'information technology',
#         'industrial and systems engineering', 'computer science',
#         'cybersecurity', 'computer science/computer engineering',
#         'psychology', 'software engineering',
#         'game design and development', 'computer engineering',
#         'computer game design and development', 'computer science e',
#         'game design', 'cyber security', 'mechatronics',
#         'industrial engineering', 'physics', 'math and cgdd', 'comp sci',
#         'it', 'information technology (cybersecurity focus)', 'undecided',
#         'computer software engineering', 'swe/cs',
#         'computer game design & development', 'cse',
#         'bsit (information technology)', 'electrical engineering',
#         'computer science engineering',
#         'computer science, computer engineering',
#         'computer science - game design', 'software engineer'],
#        dtype=object),
#  array([nan, 'female', 'male', 'man', 'he/him/male', 'make', 'm'],
#        dtype=object),
#  array([nan, 'hispanic', 'asian/white', 'white', 'asian', 'multiracial',
#         'african american', 'caucasian', 'mixed', 'mixed black and white',
#         'black', 'white/non-hispanic', 'black =', 'black/white',
#         'asian/chinese', 'caucasian-asian', 'slavic', 'indian', 'human',
#         'mixed (caucasian/hispanic)', 'white/caucasian', 'black...',
#         'black/african american', 'indian american', 'african-american',
#         'latino', 'latin', 'b/w', 'asian indian', 'puerto rican', 'w',
#         'african american/black', 'white (ethnicity : hispanic)',
#         'white/ hispanic', 'black or african american'], dtype=object))

# %%
# Define mappings for standardizing the categories
gender_mapping = {
    "man": "male",
    "he/him/male": "male",
    "make": "male",
    "m": "male",
    "female ": "female",
    "male ": "male",
}

race_mapping = {
    "african american": "black",
    "african american/black": "black",
    "black or african american": "black",
    "black...": "black",
    "black =": "black",
    "black/african american": "black",
    "african-american": "black",
    "black...": "black",
    "african-american ": "black",
    "african american ": "black",
    "caucasian": "white",
    "white/caucasian": "white",
    "white/non-hispanic": "white",
    "white (ethnicity : hispanic)": "white",
    "white/ hispanic": "white",
    "caucasian ": "white",
    "white ": "white",
}

# Apply the mappings to the data
data_new["Gender:"] = data_new["Gender:"].replace(gender_mapping)
data_new["Race:"] = data_new["Race:"].replace(race_mapping)

# Display the unique values in each of these columns after the mapping
major_unique = data_new["Major:"].unique()
gender_unique = data_new["Gender:"].unique()
race_unique = data_new["Race:"].unique()



major_unique, gender_unique, race_unique
# Out:
# (array(['re', 'information technology',
#         'industrial and systems engineering', 'computer science',
#         'cybersecurity', 'computer science/computer engineering',
#         'psychology', 'software engineering',
#         'game design and development', 'computer engineering',
#         'computer game design and development', 'computer science e',
#         'game design', 'cyber security', 'mechatronics',
#         'industrial engineering', 'physics', 'math and cgdd', 'comp sci',
#         'it', 'information technology (cybersecurity focus)', 'undecided',
#         'computer software engineering', 'swe/cs',
#         'computer game design & development', 'cse',
#         'bsit (information technology)', 'electrical engineering',
#         'computer science engineering',
#         'computer science, computer engineering',
#         'computer science - game design', 'software engineer'],
#        dtype=object),
#  array([nan, 'female', 'male'], dtype=object),
#  array([nan, 'hispanic', 'asian/white', 'white', 'asian', 'multiracial',
#         'black', 'mixed', 'mixed black and white', 'black/white',
#         'asian/chinese', 'caucasian-asian', 'slavic', 'indian', 'human',
#         'mixed (caucasian/hispanic)', 'indian american', 'latino', 'latin',
#         'b/w', 'asian indian', 'puerto rican', 'w'], dtype=object))

# %%
# Define a mapping for the Likert scale responses
likert_mapping = {
    "Strongly disagree": 1,
    "Disagree": 2,
    "Neutral": 3,
    "Agree": 4,
    "Strongly agree": 5
}

# Apply the mapping to the Likert scale columns
likert_columns = data_new.columns[4:]
data_new[likert_columns] = data_new[likert_columns].replace(likert_mapping)

# Display the first few rows of the dataframe to confirm the changes
data_new.head()
# Out:
#                                Major: Course ID/Section : Gender:  \
# 0                                  re                  er     NaN
# 1              information technology       CSE 1321L/W#1     NaN
# 2  industrial and systems engineering            CSE 1321  female
# 3                    computer science            CSE 1300    male
# 4                       cybersecurity                 WJ1  female
#
#          Race:  \
# 0          NaN
# 1          NaN
# 2     hispanic
# 3  asian/white
# 4        white
#
#   I can hold as true and integrate seemingly conflicting or contradictory points of view   \
# 0                                 Strongly disagree
# 1                                                  4
# 2                                                  3
# 3                                                  5
# 4                                                  4
#
#   To solve problems, I draw on my ability to hold, accept and go beyond paradoxes  \
# 0                                 Strongly disagree
# 1                                                  4
# 2                                                  3
# 3                                                  5
# 4                                                  4
#
#   I can offer new ways of looking at a problem  \
# 0                           Strongly disagree
# 1                                            4
# 2                                            3
# 3                                            4
# 4                                            4
#
#   I find unusual ways to solve a problem   \
# 0                      Strongly disagree
# 1                                       4
# 2                                       3
# 3                                       5
# 4                                       4
#
#   I display curiosity about many things   \
# 0                     Strongly disagree
# 1                                      4
# 2                                      4
# 3                                      5
# 4                                      4
#
#   I am willing to change my mind and try something else   ...  \
# 0                                 Strongly disagree       ...
# 1                                                  5      ...
# 2                                                  4      ...
# 3                                                  5      ...
# 4                                                  5      ...
#
#   I understand that there are shared knowledge and skills between team members  \
# 0                                                  1
# 1                                                  5
# 2                                                  4
# 3                                                  5
# 4                                                  4
#
#   I can create a cooperative atmosphere among the members when addressing problems  \
# 0                                                  1
# 1                                                  5
# 2                                                  4
# 3                                                  5
# 4                                                  4
#
#   I can listen to and consider other members' opinions  \
# 0                                                  1
# 1                                                  5
# 2                                                  4
# 3                                                  5
# 4                                                  4
#
#    I am willing to ask others for help  I can trust other team members  \
# 0                                    1                               1
# 1                                    5                               3
# 2                                    4                               4
# 3                                    5                               5
# 4                                    4                               3
#
#    I can set aside differences when working with others to achieve a common goal  \
# 0                                                  1
# 1                                                  4
# 2                                                  4
# 3                                                  5
# 4                                                  4
#
#    I like experiencing cooperative learning together with my group/ friends  \
# 0                                                  1
# 1                                                  4
# 2                                                  4
# 3                                                  5
# 4                                                  3
#
#    In cooperative learning, I think I attain more success  \
# 0                                                  1
# 1                                                  4
# 2                                                  4
# 3                                                  5
# 4                                                  3
#
#    I like solving problems related to group projects together with my friends in cooperative learning  \
# 0                                                  1
# 1                                                  3
# 2                                                  4
# 3                                                  5
# 4                                                  3
#
#    More ideas occur in cooperative learning
# 0                                         1
# 1                                         4
# 2                                         4
# 3                                         5
# 4                                         4
#
# [5 rows x 54 columns]

# %%
import numpy as np

# %%
# 1. Convert all Likert scale responses to numeric values
data_new[likert_columns] = data_new[likert_columns].apply(pd.to_numeric, errors='coerce')

# 2. Flatten the Likert scale responses into a single array (from a DataFrame format to a 1D array)
likert_data_flat = data_new[likert_columns].values.flatten()

# 3. Filter out any NaN values from the array (this step ensures that any non-numeric values are excluded)
likert_data_flat = likert_data_flat[~np.isnan(likert_data_flat)]

# 4. Count the number of each type of response (from 1 to 5)
category_counts = pd.value_counts(likert_data_flat, sort=False)

# 5. Calculate the percentage distribution of each type of response
overall_percentages = (category_counts / len(likert_data_flat)) * 100

# 6. Sort the percentages in ascending order of response type
overall_percentages.sort_index()
# Out:
# 1.0     1.660448
# 2.0     7.145522
# 3.0    19.514925
# 4.0    42.826493
# 5.0    28.852612
# dtype: float64

# %%
# Function to calculate percentage for each category based on Major, Gender and Race
def calculate_percentages(category_field, category):
    # Filter the main data to get rows that match the given category and value.
    # For instance, if category_field is "Major:" and category is "Engineering",
    # it fetches all rows of students majoring in Engineering.
    data_category = data_new[data_new[category_field] == category][likert_columns]
    
    # Convert the 2D data (rows of Likert responses) to a 1D array for ease of processing.
    likert_data_flat = data_category.values.flatten()
    
    # Remove any NaN values from the array. This is essential for accurate percentage calculation.
    likert_data_flat = likert_data_flat[~np.isnan(likert_data_flat)]
    
    # Calculate the total number of responses in the flattened array.
    total_responses_category = len(likert_data_flat)
    
    # Count the occurrences of each Likert scale response (e.g., how many times was "Strongly Agree" chosen).
    category_counts = pd.value_counts(likert_data_flat, sort=False)
    
    # Calculate the percentage for each Likert scale response.
    percentages = (category_counts / total_responses_category) * 100
    
    # Return the sorted percentages. This ensures the order is from "Strongly disagree" to "Strongly agree".
    return percentages.sort_index()

# For each unique Major in the dataset, apply the calculate_percentages function.
# This computes the percentage distribution of Likert responses for every Major.
major_percentages = {major: calculate_percentages("Major:", major) for major in major_unique}

# Similarly, calculate the percentages for each unique value in the "Gender:" category.
gender_percentages = {gender: calculate_percentages("Gender:", gender) for gender in gender_unique}

# Similarly, calculate the percentages for each unique value in the "Race:" category.
race_percentages = {race: calculate_percentages("Race:", race) for race in race_unique}

major_percentages, gender_percentages, race_percentages
# Out:
# ({'re': 1.0    100.0
#   dtype: float64,
#   'information technology': 1.0     1.291156
#   2.0    10.329245
#   3.0    25.306649
#   4.0    41.768883
#   5.0    21.304067
#   dtype: float64,
#   'industrial and systems engineering': 2.0     5.050505
#   3.0    28.282828
#   4.0    62.626263
#   5.0     4.040404
#   dtype: float64,
#   'computer science': 1.0     1.486200
#   2.0     6.605331
#   3.0    17.480538
#   4.0    42.958245
#   5.0    31.469686
#   dtype: float64,
#   'cybersecurity': 1.0     1.2
#   2.0     7.0
#   3.0    23.0
#   4.0    51.4
#   5.0    17.4
#   dtype: float64,
#   'computer science/computer engineering': 1.0     2.0
#   2.0    12.0
#   3.0     2.0
#   4.0    50.0
#   5.0    34.0
#   dtype: float64,
#   'psychology': 1.0     2.0
#   2.0     3.0
#   3.0    26.0
#   4.0    52.0
#   5.0    17.0
#   dtype: float64,
#   'software engineering': 1.0     1.436782
#   2.0     7.567050
#   3.0    18.486590
#   4.0    39.942529
#   5.0    32.567050
#   dtype: float64,
#   'game design and development': 2.0     4.0
#   3.0    12.5
#   4.0    41.5
#   5.0    42.0
#   dtype: float64,
#   'computer engineering': 1.0     0.364299
#   2.0     6.375228
#   3.0    21.857923
#   4.0    39.708561
#   5.0    31.693989
#   dtype: float64,
#   'computer game design and development': 1.0     0.333333
#   2.0    12.000000
#   3.0    23.666667
#   4.0    46.333333
#   5.0    17.666667
#   dtype: float64,
#   'computer science e': 1.0     2.0
#   2.0    16.0
#   3.0    32.0
#   4.0    30.0
#   5.0    20.0
#   dtype: float64,
#   'game design': 1.0     2.0
#   2.0    13.0
#   3.0    31.0
#   4.0    36.0
#   5.0    18.0
#   dtype: float64,
#   'cyber security': 1.0     1.111111
#   2.0     3.111111
#   3.0    12.888889
#   4.0    45.777778
#   5.0    37.111111
#   dtype: float64,
#   'mechatronics': 2.0     7.5
#   3.0    24.5
#   4.0    52.5
#   5.0    15.5
#   dtype: float64,
#   'industrial engineering': 2.0     4.0
#   3.0    25.0
#   4.0    59.0
#   5.0    12.0
#   dtype: float64,
#   'physics': 2.0     2.0
#   3.0     2.0
#   4.0    68.0
#   5.0    28.0
#   dtype: float64,
#   'math and cgdd': 3.0     2.0
#   4.0    30.0
#   5.0    68.0
#   dtype: float64,
#   'comp sci': 3.0    12.0
#   4.0    44.0
#   5.0    44.0
#   dtype: float64,
#   'it': 2.0     4.666667
#   3.0    15.333333
#   4.0    48.000000
#   5.0    32.000000
#   dtype: float64,
#   'information technology (cybersecurity focus)': 2.0     2.0
#   3.0    10.0
#   4.0    60.0
#   5.0    28.0
#   dtype: float64,
#   'undecided': 2.0     4.0
#   3.0    36.0
#   4.0    52.0
#   5.0     8.0
#   dtype: float64,
#   'computer software engineering': 2.0     4.0
#   3.0    14.0
#   4.0    44.0
#   5.0    38.0
#   dtype: float64,
#   'swe/cs': 3.0    10.0
#   4.0    60.0
#   5.0    30.0
#   dtype: float64,
#   'computer game design & development': 1.0     2.0
#   2.0    14.0
#   3.0    12.0
#   4.0    38.0
#   5.0    34.0
#   dtype: float64,
#   'cse': 3.0    16.0
#   4.0    18.0
#   5.0    66.0
#   dtype: float64,
#   'bsit (information technology)': 3.0    16.0
#   4.0    38.0
#   5.0    46.0
#   dtype: float64,
#   'electrical engineering': 1.0     3.010033
#   2.0     4.347826
#   3.0    23.076923
#   4.0    29.096990
#   5.0    40.468227
#   dtype: float64,
#   'computer science engineering': 2.0    10.0
#   3.0    36.0
#   4.0    44.0
#   5.0    10.0
#   dtype: float64,
#   'computer science, computer engineering': 1.0     4.0
#   2.0     4.0
#   3.0    14.0
#   4.0    42.0
#   5.0    36.0
#   dtype: float64,
#   'computer science - game design': 1.0    14.0
#   2.0    48.0
#   3.0    22.0
#   4.0    16.0
#   dtype: float64,
#   'software engineer': 2.0     2.0
#   3.0    16.0
#   4.0    26.0
#   5.0    56.0
#   dtype: float64},
#  {nan: Series([], dtype: float64),
#   'female': 1.0     2.006832
#   2.0     6.148591
#   3.0    20.452605
#   4.0    45.004270
#   5.0    26.387703
#   dtype: float64,
#   'male': 1.0     1.091563
#   2.0     7.551047
#   3.0    19.262874
#   4.0    41.838962
#   5.0    30.255554
#   dtype: float64},
#  {nan: Series([], dtype: float64),
#   'hispanic': 1.0     0.182149
#   2.0     6.739526
#   3.0    21.675774
#   4.0    41.530055
#   5.0    29.872495
#   dtype: float64,
#   'asian/white': 1.0     4.0
#   2.0     2.0
#   4.0    12.0
#   5.0    82.0
#   dtype: float64,
#   'white': 1.0     1.200505
#   2.0     8.277169
#   3.0    17.860152
#   4.0    43.660489
#   5.0    29.001685
#   dtype: float64,
#   'asian': 1.0     0.401875
#   2.0     6.965841
#   3.0    23.040857
#   4.0    41.125251
#   5.0    28.466175
#   dtype: float64,
#   'multiracial': 1.0     4.0
#   2.0     6.0
#   3.0    34.0
#   4.0    30.0
#   5.0    26.0
#   dtype: float64,
#   'black': 1.0     2.211055
#   2.0     6.633166
#   3.0    20.804020
#   4.0    43.969849
#   5.0    26.381910
#   dtype: float64,
#   'mixed': 1.0     0.666667
#   2.0     3.333333
#   3.0    15.333333
#   4.0    46.000000
#   5.0    34.666667
#   dtype: float64,
#   'mixed black and white': 3.0     2.0
#   4.0    20.0
#   5.0    78.0
#   dtype: float64,
#   'black/white': 2.0     4.0
#   3.0    22.0
#   4.0    60.0
#   5.0    14.0
#   dtype: float64,
#   'asian/chinese': 3.0     2.0
#   4.0    30.0
#   5.0    68.0
#   dtype: float64,
#   'caucasian-asian': 1.0     6.0
#   2.0    18.0
#   3.0    46.0
#   4.0    30.0
#   dtype: float64,
#   'slavic': 2.0    14.0
#   3.0    18.0
#   4.0    26.0
#   5.0    42.0
#   dtype: float64,
#   'indian': 2.0     4.0
#   3.0    24.0
#   4.0    34.0
#   5.0    38.0
#   dtype: float64,
#   'human': 1.0     4.0
#   2.0     4.0
#   3.0    36.0
#   4.0    36.0
#   5.0    20.0
#   dtype: float64,
#   'mixed (caucasian/hispanic)': 1.0     6.0
#   2.0     8.0
#   3.0    28.0
#   4.0    52.0
#   5.0     6.0
#   dtype: float64,
#   'indian american': 1.0    10.0
#   2.0    10.0
#   3.0    36.0
#   4.0    34.0
#   5.0    10.0
#   dtype: float64,
#   'latino': 1.0     3.0
#   2.0     6.0
#   3.0    16.0
#   4.0    40.0
#   5.0    35.0
#   dtype: float64,
#   'latin': 3.0    10.0
#   4.0    58.0
#   5.0    32.0
#   dtype: float64,
#   'b/w': 2.0     2.0
#   3.0    10.0
#   4.0    34.0
#   5.0    54.0
#   dtype: float64,
#   'asian indian': 2.0     2.0
#   3.0    32.0
#   4.0    36.0
#   5.0    30.0
#   dtype: float64,
#   'puerto rican': 3.0    20.0
#   4.0    26.0
#   5.0    54.0
#   dtype: float64,
#   'w': 3.0    10.204082
#   4.0    16.326531
#   5.0    73.469388
#   dtype: float64})

# %%
# Converting the major_percentages dictionary to a DataFrame for easy plotting
major_percentages_df = pd.DataFrame(major_percentages).transpose().fillna(0)

# Plotting the response percentages for each major as a stacked bar chart
major_percentages_df.plot(kind='bar', stacked=True, figsize=(12, 6), cmap='viridis', edgecolor='black')

# Adding details to the plot
plt.title('Response Percentages by Major')
plt.ylabel('Percentage')
plt.xlabel('Major')
plt.legend(title='Likert Scale Response', loc='upper left', bbox_to_anchor=(1, 1))
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

plt.show()

# %%
# Converting the gender_percentages and race_percentages dictionaries to DataFrames for easy plotting
gender_percentages_df = pd.DataFrame(gender_percentages).transpose().fillna(0)
race_percentages_df = pd.DataFrame(race_percentages).transpose().fillna(0)

# Plotting the response percentages for each gender
gender_percentages_df.plot(kind='bar', stacked=True, figsize=(10, 5), cmap='viridis', edgecolor='black')

# Adding details to the plot
plt.title('Response Percentages by Gender')
plt.ylabel('Percentage')
plt.xlabel('Gender')
plt.legend(title='Likert Scale Response', loc='upper left', bbox_to_anchor=(1, 1))
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

plt.show()

# Plotting the response percentages for each race
race_percentages_df.plot(kind='bar', stacked=True, figsize=(12, 6), cmap='viridis', edgecolor='black')

# Adding details to the plot
plt.title('Response Percentages by Race')
plt.ylabel('Percentage')
plt.xlabel('Race')
plt.legend(title='Likert Scale Response', loc='upper left', bbox_to_anchor=(1, 1))
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

plt.show()
