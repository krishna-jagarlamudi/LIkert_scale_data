# %%
import pandas as pd

# %%
# Load the data
data_new = pd.read_excel("/Users/krishnajagarlamudi/Downloads/F2BLD.XLSX")

# Display the first few rows of the dataframe
data_new.head()
# Out:
#                          Major:  \
# 0             Computer science
# 1             Computer Science
# 2        Information Technology
# 3  Game Design and Development
# 4             Computer Science
#
#   Course ID/Section : (CSE 1300 OR CSE 1321 OR CSE 1322) Gender:  \
# 0                                           CSE 1300        Male
# 1                                           CSE 1300        Male
# 2                                           CSE 1300        Male
# 3                                           CSE 1300        Male
# 4                                           CSE 1300      Female
#
#                     Race:  \
# 0                  Asian
# 1                 African
# 2                   White
# 3  Black/African American
# 4                   White
#
#   To solve problems, I draw on my ability to hold, accept and go beyond paradoxes  \
# 0                                            Neutral
# 1                                              Agree
# 2                                              Agree
# 3                                            Neutral
# 4                                     Strongly agree
#
#   I can hold as true and integrate seemingly conflicting or contradictory points of view   \
# 0                                              Agree
# 1                                            Neutral
# 2                                              Agree
# 3                                              Agree
# 4                                            Neutral
#
#   I can offer new ways of looking at a problem  \
# 0                               Strongly agree
# 1                                        Agree
# 2                                        Agree
# 3                                        Agree
# 4                                     Disagree
#
#   I find unusual ways to solve a problem   \
# 0                                   Agree
# 1                          Strongly agree
# 2                                   Agree
# 3                                   Agree
# 4                      Strongly disagree
#
#   I display curiosity about many things   \
# 0                         Strongly agree
# 1                                  Agree
# 2                                  Agree
# 3                         Strongly agree
# 4                         Strongly agree
#
#   I am willing to change my mind and try something else   ...  \
# 0                                     Strongly agree      ...
# 1                                              Agree      ...
# 2                                              Agree      ...
# 3                                              Agree      ...
# 4                                     Strongly agree      ...
#
#   I understand that there are shared knowledge and skills between team members  \
# 0                                     Strongly agree
# 1                                            Neutral
# 2                                     Strongly agree
# 3                                              Agree
# 4                                              Agree
#
#   I can create a cooperative atmosphere among the members when addressing problems  \
# 0                                     Strongly agree
# 1                                            Neutral
# 2                                     Strongly agree
# 3                                            Neutral
# 4                                           Disagree
#
#   I can listen to and consider other members' opinions  \
# 0                                     Strongly agree
# 1                                              Agree
# 2                                     Strongly agree
# 3                                              Agree
# 4                                            Neutral
#
#   I am willing to ask others for help I can trust other team members  \
# 0                      Strongly agree                 Strongly agree
# 1                               Agree                        Neutral
# 2                      Strongly agree                 Strongly agree
# 3                             Neutral                       Disagree
# 4                               Agree                        Neutral
#
#   I can set aside differences when working with others to achieve a common goal  \
# 0                                     Strongly agree
# 1                                              Agree
# 2                                     Strongly agree
# 3                                            Neutral
# 4                                              Agree
#
#   I like experiencing cooperative learning together with my group/ friends  \
# 0                                     Strongly agree
# 1                                            Neutral
# 2                                     Strongly agree
# 3                                            Neutral
# 4                                           Disagree
#
#   In cooperative learning, I think I attain more success  \
# 0                                     Strongly agree
# 1                                            Neutral
# 2                                     Strongly agree
# 3                                            Neutral
# 4                                           Disagree
#
#   I like solving problems related to group projects together with my friends in cooperative learning  \
# 0                                     Strongly agree
# 1                                            Neutral
# 2                                     Strongly agree
# 3                                            Neutral
# 4                                           Disagree
#
#   More ideas occur in cooperative learning
# 0                           Strongly agree
# 1                                    Agree
# 2                           Strongly agree
# 3                           Strongly agree
# 4                                  Neutral
#
# [5 rows x 54 columns]

# %%
# Standardize the Major, Gender, and Race categories
data_new["Major:"] = data_new["Major:"].str.lower().str.strip()
data_new["Gender:"] = data_new["Gender:"].str.lower().str.strip()
data_new["Race:"] = data_new["Race:"].str.lower().str.strip()

# Display the unique values in each of these columns
major_unique = data_new["Major:"].unique()
gender_unique = data_new["Gender:"].unique()
race_unique = data_new["Race:"].unique()

major_unique, gender_unique, race_unique
# Out:
# (array(['computer science', 'information technology',
#         'game design and development', 'computer science engineering',
#         'computer game design', 'computer science and interactive design',
#         'cybersecurity', 'computer scienc', 'software engineering',
#         'bachelor of science software engineering',
#         'computer/political science', 'bsswe', 'basit', 'game design',
#         'cyber security', 'information systems', 'electrical engineering',
#         'swe', 'cgdd', 'master of cyber security', 'mechatronics',
#         'computer engineering', 'undecide/computer science',
#         'computer game design and development',
#         'bachelor of science in computer game design and development',
#         'art/ math', 'computer science and biology',
#         'computer science emphasis ai/ml', 'peraltilla'], dtype=object),
#  array(['male', 'female', nan, 'non-binary',
#         'female, as observed at birth'], dtype=object),
#  array(['asian', 'african', 'white', 'black/african american',
#         'african american', 'black or african american', nan, 'hispanic',
#         'hispanic/white', 'caucasian', 'black', 'whit', 'hispanic/latino',
#         'white/east asian', 'white and hispanic', 'latina',
#         'native american', 'southeast asian', 'half white, half hispanic',
#         'african american/black'], dtype=object))

# %%
# Define mappings for standardizing the categories
gender_mapping = {
    "man": "male",
    "he/him/male": "male",
    "make": "male",
    "m": "male",
    "female ": "female",
    "male ": "male",
}

race_mapping = {
    "african american": "black",
    "african american/black": "black",
    "black or african american": "black",
    "black...": "black",
    "black =": "black",
    "black/african american": "black",
    "african-american": "black",
    "black...": "black",
    "african-american ": "black",
    "african american ": "black",
    "caucasian": "white",
    "white/caucasian": "white",
    "white/non-hispanic": "white",
    "white (ethnicity : hispanic)": "white",
    "white/ hispanic": "white",
    "caucasian ": "white",
    "white ": "white",
}

# Apply the mappings to the data
data_new["Gender:"] = data_new["Gender:"].replace(gender_mapping)
data_new["Race:"] = data_new["Race:"].replace(race_mapping)

# Display the unique values in each of these columns after the mapping
major_unique = data_new["Major:"].unique()
gender_unique = data_new["Gender:"].unique()
race_unique = data_new["Race:"].unique()

major_unique, gender_unique, race_unique
# Out:
# (array(['computer science', 'information technology',
#         'game design and development', 'computer science engineering',
#         'computer game design', 'computer science and interactive design',
#         'cybersecurity', 'computer scienc', 'software engineering',
#         'bachelor of science software engineering',
#         'computer/political science', 'bsswe', 'basit', 'game design',
#         'cyber security', 'information systems', 'electrical engineering',
#         'swe', 'cgdd', 'master of cyber security', 'mechatronics',
#         'computer engineering', 'undecide/computer science',
#         'computer game design and development',
#         'bachelor of science in computer game design and development',
#         'art/ math', 'computer science and biology',
#         'computer science emphasis ai/ml', 'peraltilla'], dtype=object),
#  array(['male', 'female', nan, 'non-binary',
#         'female, as observed at birth'], dtype=object),
#  array(['asian', 'african', 'white', 'black', nan, 'hispanic',
#         'hispanic/white', 'whit', 'hispanic/latino', 'white/east asian',
#         'white and hispanic', 'latina', 'native american',
#         'southeast asian', 'half white, half hispanic'], dtype=object))

# %%
# Define a mapping for the Likert scale responses
likert_mapping = {
    "Strongly disagree": 1,
    "Disagree": 2,
    "Neutral": 3,
    "Agree": 4,
    "Strongly agree": 5
}

# Apply the mapping to the Likert scale columns
likert_columns = data_new.columns[4:]
data_new[likert_columns] = data_new[likert_columns].replace(likert_mapping)

# Display the first few rows of the dataframe to confirm the changes
data_new.head()
# Out:
#                         Major:  \
# 0             computer science
# 1             computer science
# 2       information technology
# 3  game design and development
# 4             computer science
#
#   Course ID/Section : (CSE 1300 OR CSE 1321 OR CSE 1322) Gender:    Race:  \
# 0                                           CSE 1300        male    asian
# 1                                           CSE 1300        male  african
# 2                                           CSE 1300        male    white
# 3                                           CSE 1300        male    black
# 4                                           CSE 1300      female    white
#
#    To solve problems, I draw on my ability to hold, accept and go beyond paradoxes  \
# 0                                                  3
# 1                                                  4
# 2                                                  4
# 3                                                  3
# 4                                                  5
#
#    I can hold as true and integrate seemingly conflicting or contradictory points of view   \
# 0                                                  4
# 1                                                  3
# 2                                                  4
# 3                                                  4
# 4                                                  3
#
#    I can offer new ways of looking at a problem  \
# 0                                             5
# 1                                             4
# 2                                             4
# 3                                             4
# 4                                             2
#
#   I find unusual ways to solve a problem   \
# 0                                       4
# 1                                       5
# 2                                       4
# 3                                       4
# 4                      Strongly disagree
#
#    I display curiosity about many things   \
# 0                                       5
# 1                                       4
# 2                                       4
# 3                                       5
# 4                                       5
#
#    I am willing to change my mind and try something else   ...  \
# 0                                                  5       ...
# 1                                                  4       ...
# 2                                                  4       ...
# 3                                                  4       ...
# 4                                                  5       ...
#
#    I understand that there are shared knowledge and skills between team members  \
# 0                                                  5
# 1                                                  3
# 2                                                  5
# 3                                                  4
# 4                                                  4
#
#   I can create a cooperative atmosphere among the members when addressing problems  \
# 0                                                  5
# 1                                                  3
# 2                                                  5
# 3                                                  3
# 4                                                  2
#
#    I can listen to and consider other members' opinions  \
# 0                                                  5
# 1                                                  4
# 2                                                  5
# 3                                                  4
# 4                                                  3
#
#    I am willing to ask others for help  I can trust other team members  \
# 0                                    5                               5
# 1                                    4                               3
# 2                                    5                               5
# 3                                    3                               2
# 4                                    4                               3
#
#    I can set aside differences when working with others to achieve a common goal  \
# 0                                                  5
# 1                                                  4
# 2                                                  5
# 3                                                  3
# 4                                                  4
#
#    I like experiencing cooperative learning together with my group/ friends  \
# 0                                                  5
# 1                                                  3
# 2                                                  5
# 3                                                  3
# 4                                                  2
#
#    In cooperative learning, I think I attain more success  \
# 0                                                  5
# 1                                                  3
# 2                                                  5
# 3                                                  3
# 4                                                  2
#
#    I like solving problems related to group projects together with my friends in cooperative learning  \
# 0                                                  5
# 1                                                  3
# 2                                                  5
# 3                                                  3
# 4                                                  2
#
#    More ideas occur in cooperative learning
# 0                                         5
# 1                                         4
# 2                                         5
# 3                                         5
# 4                                         3
#
# [5 rows x 54 columns]

# %%
import numpy as np

# %%
# 1. Convert all Likert scale responses to numeric values
data_new[likert_columns] = data_new[likert_columns].apply(pd.to_numeric, errors='coerce')

# 2. Flatten the Likert scale responses into a single array (from a DataFrame format to a 1D array)
likert_data_flat = data_new[likert_columns].values.flatten()

# 3. Filter out any NaN values from the array (this step ensures that any non-numeric values are excluded)
likert_data_flat = likert_data_flat[~np.isnan(likert_data_flat)]

# 4. Count the number of each type of response (from 1 to 5)
category_counts = pd.value_counts(likert_data_flat, sort=False)

# 5. Calculate the percentage distribution of each type of response
overall_percentages = (category_counts / len(likert_data_flat)) * 100

# 6. Sort the percentages in ascending order of response type
overall_percentages.sort_index()
# Out:
# 1.0     0.641026
# 2.0     5.497280
# 3.0    18.006993
# 4.0    40.986791
# 5.0    34.867910
# dtype: float64

# %%
# Function to calculate percentage for each category based on Major, Gender and Race
def calculate_percentages(category_field, category):
    # Filter the main data to get rows that match the given category and value.
    # For instance, if category_field is "Major:" and category is "Engineering",
    # it fetches all rows of students majoring in Engineering.
    data_category = data_new[data_new[category_field] == category][likert_columns]
    
    # Convert the 2D data (rows of Likert responses) to a 1D array for ease of processing.
    likert_data_flat = data_category.values.flatten()
    
    # Remove any NaN values from the array. This is essential for accurate percentage calculation.
    likert_data_flat = likert_data_flat[~np.isnan(likert_data_flat)]
    
    # Calculate the total number of responses in the flattened array.
    total_responses_category = len(likert_data_flat)
    
    # Count the occurrences of each Likert scale response (e.g., how many times was "Strongly Agree" chosen).
    category_counts = pd.value_counts(likert_data_flat, sort=False)
    
    # Calculate the percentage for each Likert scale response.
    percentages = (category_counts / total_responses_category) * 100
    
    # Return the sorted percentages. This ensures the order is from "Strongly disagree" to "Strongly agree".
    return percentages.sort_index()

# For each unique Major in the dataset, apply the calculate_percentages function.
# This computes the percentage distribution of Likert responses for every Major.
major_percentages = {major: calculate_percentages("Major:", major) for major in major_unique}

# Similarly, calculate the percentages for each unique value in the "Gender:" category.
gender_percentages = {gender: calculate_percentages("Gender:", gender) for gender in gender_unique}

# Similarly, calculate the percentages for each unique value in the "Race:" category.
race_percentages = {race: calculate_percentages("Race:", race) for race in race_unique}

major_percentages, gender_percentages, race_percentages
# Out:
# ({'computer science': 1.0     0.170285
#   2.0     5.576841
#   3.0    19.369945
#   4.0    41.251596
#   5.0    33.631332
#   dtype: float64,
#   'information technology': 1.0     5.333333
#   2.0     2.666667
#   3.0    11.333333
#   4.0    22.666667
#   5.0    58.000000
#   dtype: float64,
#   'game design and development': 2.0     7.382550
#   3.0    22.147651
#   4.0    49.664430
#   5.0    20.805369
#   dtype: float64,
#   'computer science engineering': 3.0    10.0
#   4.0    67.0
#   5.0    23.0
#   dtype: float64,
#   'computer game design': 2.0    10.0
#   3.0    30.0
#   4.0    46.0
#   5.0    14.0
#   dtype: float64,
#   'computer science and interactive design': 1.0     2.0
#   2.0    20.0
#   3.0    32.0
#   4.0    40.0
#   5.0     6.0
#   dtype: float64,
#   'cybersecurity': 1.0     1.000000
#   2.0     3.000000
#   3.0     9.000000
#   4.0    33.333333
#   5.0    53.666667
#   dtype: float64,
#   'computer scienc': 2.0     8.0
#   3.0    14.0
#   4.0    46.0
#   5.0    32.0
#   dtype: float64,
#   'software engineering': 1.0     0.923077
#   2.0     4.153846
#   3.0    20.307692
#   4.0    46.769231
#   5.0    27.846154
#   dtype: float64,
#   'bachelor of science software engineering': 4.0     4.0
#   5.0    96.0
#   dtype: float64,
#   'computer/political science': 2.0     4.0
#   3.0    36.0
#   4.0    56.0
#   5.0     4.0
#   dtype: float64,
#   'bsswe': 2.0     2.0
#   3.0    10.0
#   4.0    12.0
#   5.0    76.0
#   dtype: float64,
#   'basit': 5.0    100.0
#   dtype: float64,
#   'game design': 1.0     0.666667
#   2.0    11.333333
#   3.0    28.666667
#   4.0    46.000000
#   5.0    13.333333
#   dtype: float64,
#   'cyber security': 1.0     3.5
#   2.0     7.5
#   3.0    28.5
#   4.0    38.5
#   5.0    22.0
#   dtype: float64,
#   'information systems': 2.0     8.0
#   3.0    20.0
#   4.0    36.0
#   5.0    36.0
#   dtype: float64,
#   'electrical engineering': 2.0    14.0
#   3.0    12.0
#   4.0    44.0
#   5.0    30.0
#   dtype: float64,
#   'swe': 1.0     2.0
#   2.0     6.0
#   3.0     4.0
#   4.0    40.0
#   5.0    48.0
#   dtype: float64,
#   'cgdd': 1.0     2.0
#   2.0     8.0
#   3.0     4.0
#   4.0    12.0
#   5.0    74.0
#   dtype: float64,
#   'master of cyber security': 4.0    26.0
#   5.0    74.0
#   dtype: float64,
#   'mechatronics': 3.0     8.0
#   4.0    78.0
#   5.0    14.0
#   dtype: float64,
#   'computer engineering': 2.0     1.0
#   3.0     7.0
#   4.0    51.0
#   5.0    41.0
#   dtype: float64,
#   'undecide/computer science': 2.0     4.0
#   3.0    12.0
#   4.0    30.0
#   5.0    54.0
#   dtype: float64,
#   'computer game design and development': 2.0    24.0
#   3.0    24.0
#   4.0    46.0
#   5.0     6.0
#   dtype: float64,
#   'bachelor of science in computer game design and development': 2.0     4.0
#   3.0    20.0
#   4.0    32.0
#   5.0    44.0
#   dtype: float64,
#   'art/ math': 2.0     2.0
#   3.0    14.0
#   4.0    60.0
#   5.0    24.0
#   dtype: float64,
#   'computer science and biology': 2.0     4.0
#   3.0    34.0
#   4.0    60.0
#   5.0     2.0
#   dtype: float64,
#   'computer science emphasis ai/ml': 1.0     2.0
#   2.0     4.0
#   3.0    16.0
#   4.0    30.0
#   5.0    48.0
#   dtype: float64,
#   'peraltilla': 2.0    14.0
#   3.0     2.0
#   4.0    32.0
#   5.0    52.0
#   dtype: float64},
#  {'male': 1.0     0.507614
#   2.0     4.449089
#   3.0    17.885936
#   4.0    41.564646
#   5.0    35.592714
#   dtype: float64,
#   'female': 1.0     1.035197
#   2.0     8.005521
#   3.0    15.873016
#   4.0    38.164251
#   5.0    36.922015
#   dtype: float64,
#   nan: Series([], dtype: float64),
#   'non-binary': 2.0    16.0
#   3.0    28.0
#   4.0    52.0
#   5.0     4.0
#   dtype: float64,
#   'female, as observed at birth': 1.0     2.0
#   2.0     8.0
#   3.0     4.0
#   4.0    12.0
#   5.0    74.0
#   dtype: float64},
#  {'asian': 1.0     0.6
#   2.0     6.6
#   3.0    15.4
#   4.0    51.6
#   5.0    25.8
#   dtype: float64,
#   'african': 2.0     4.0
#   3.0    32.0
#   4.0    56.0
#   5.0     8.0
#   dtype: float64,
#   'white': 1.0     0.537109
#   2.0     5.761719
#   3.0    17.382812
#   4.0    35.693359
#   5.0    40.625000
#   dtype: float64,
#   'black': 1.0     0.916667
#   2.0     4.500000
#   3.0    17.750000
#   4.0    43.666667
#   5.0    33.166667
#   dtype: float64,
#   nan: Series([], dtype: float64),
#   'hispanic': 1.0     0.75
#   2.0     7.50
#   3.0    15.75
#   4.0    30.75
#   5.0    45.25
#   dtype: float64,
#   'hispanic/white': 1.0     2.0
#   2.0     6.0
#   3.0    10.0
#   4.0    44.0
#   5.0    38.0
#   dtype: float64,
#   'whit': 1.0     2.0
#   2.0    22.0
#   3.0    18.0
#   4.0    36.0
#   5.0    22.0
#   dtype: float64,
#   'hispanic/latino': 2.0     6.0
#   3.0    12.0
#   4.0    42.0
#   5.0    40.0
#   dtype: float64,
#   'white/east asian': 2.0     8.0
#   3.0    22.0
#   4.0    52.0
#   5.0    18.0
#   dtype: float64,
#   'white and hispanic': 1.0     2.0
#   2.0    16.0
#   3.0    12.0
#   4.0    36.0
#   5.0    34.0
#   dtype: float64,
#   'latina': 3.0    20.0
#   4.0    34.0
#   5.0    46.0
#   dtype: float64,
#   'native american': 1.0     2.0
#   2.0     8.0
#   3.0     4.0
#   4.0    12.0
#   5.0    74.0
#   dtype: float64,
#   'southeast asian': 3.0    24.0
#   4.0    64.0
#   5.0    12.0
#   dtype: float64,
#   'half white, half hispanic': 2.0     2.0
#   3.0    14.0
#   4.0    60.0
#   5.0    24.0
#   dtype: float64})

# %%
import matplotlib.pyplot as plt
# Converting the major_percentages dictionary to a DataFrame for easy plotting
major_percentages_df = pd.DataFrame(major_percentages).transpose().fillna(0)

# Plotting the response percentages for each major as a stacked bar chart
major_percentages_df.plot(kind='bar', stacked=True, figsize=(12, 6), cmap='viridis', edgecolor='black')

# Adding details to the plot
plt.title('Response Percentages by Major')
plt.ylabel('Percentage')
plt.xlabel('Major')
plt.legend(title='Likert Scale Response', loc='upper left', bbox_to_anchor=(1, 1))
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

plt.show()

# %%
# Converting the gender_percentages and race_percentages dictionaries to DataFrames for easy plotting
gender_percentages_df = pd.DataFrame(gender_percentages).transpose().fillna(0)
race_percentages_df = pd.DataFrame(race_percentages).transpose().fillna(0)

# Plotting the response percentages for each gender
gender_percentages_df.plot(kind='bar', stacked=True, figsize=(10, 5), cmap='viridis', edgecolor='black')

# Adding details to the plot
plt.title('Response Percentages by Gender')
plt.ylabel('Percentage')
plt.xlabel('Gender')
plt.legend(title='Likert Scale Response', loc='upper left', bbox_to_anchor=(1, 1))
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

plt.show()

# Plotting the response percentages for each race
race_percentages_df.plot(kind='bar', stacked=True, figsize=(12, 6), cmap='viridis', edgecolor='black')

# Adding details to the plot
plt.title('Response Percentages by Race')
plt.ylabel('Percentage')
plt.xlabel('Race')
plt.legend(title='Likert Scale Response', loc='upper left', bbox_to_anchor=(1, 1))
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

plt.show()
